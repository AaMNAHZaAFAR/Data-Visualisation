# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")

display(data)
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
def line_graph():
    
    return G

G = data.plot(x="Rank", y=["P25th", "Median", "P75th"])
plt.xlabel("Rank")
plt.ylabel("Earning")
plt.title('Line Graph',
          fontweight ="bold")
plt.legend(loc="upper right")
plt.show()

# %%
def Box_graph():
    
    return bp

bp = data.plot( y=["P25th", "Median", "P75th"], kind="box", notch=False, patch_artist=True, boxprops=dict(color='red'))
plt.xlabel("Earning")
plt.ylabel("Rank")
plt.title('Boxplot',
          fontweight ="bold")

plt.legend(["P25th", "Median", "P75th"], loc='upper right')
plt.show()

# %%
def H_graph():
    
    return HG
    
HG = data.plot(x="Rank", y=["P25th", "Median", "P75th"], kind="hist", bins=20)
plt.style.use("bmh")
plt.xlabel("Earning")
plt.ylabel("Rank")
plt.title('Histogarm',
          fontweight ="bold")
  
plt.show()
